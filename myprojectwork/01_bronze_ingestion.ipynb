# %%
raw_path = "s3a://bank-churn-samba-bucket/raw/bank-data/bank-customer-churn-prediction.csv"

df_bronze = (
    spark.read
        .option("header", True)
        .option("inferSchema", True)
        .csv(raw_path)
)

df_bronze.write.format("delta").mode("overwrite").saveAsTable(
    "churn_catalog.raw.customer_data"
)

# %% [markdown]
# #  BRONZE LAYER SUMMARY

# %%
print("Bronze Layer Summary")

print("Total rows ingested:", df_bronze.count())

print("Source path:", raw_path)

print("Columns:", df_bronze.columns)

display(df_bronze.limit(5))
